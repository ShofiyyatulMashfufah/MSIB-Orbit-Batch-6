# %% [markdown]
# ![diri.jpg](data:image/jpeg;base64,...)

# %%
print("\nSeorang manusia biasa yang mengagumi indahnya AI\n")

input("Nama            : ")
input("Jenis Kelamin   : ")
input("Alamat          : ")
input("Hobi            : ")
input("Pendidikan      : ")
input("Pekerjaan       : ")
input("Media Sosial    : ")
input("Kutipan Favorit : \n")
input("\nPengalaman      : \n \t-")
# Out:
# Seorang manusia biasa yang mengagumi indahnya AI
#
# Nama            : Shofiyyatul Mashfufah
# Jenis Kelamin   : Perempuan
# Alamat          : Garut
# Hobi            : Mendengarkan Musik
# Pendidikan      : S1-Teknik Informatika
# Pekerjaan       : Belum bekerja
# Media Sosial    : fufahsm_05
# Kutipan Favorit :
# "Jagalah shalatmu. Karena saat kamu kehilangan shalat, maka kamu akan kehilangan segalanya"
#
# Pengalaman      :
#  	-Anggota OSIS SMP
# 'Anggota OSIS SMP'
